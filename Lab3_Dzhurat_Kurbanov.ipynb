# %% [markdown]
# # Лабораторная работа 3 Курбанов Джурат AIN-1-21

# %% [markdown]
# #### 1.	Изучить теоретический материал и примеры, приведенные в описании

# %% [markdown]
# # ✓

# %% [markdown]
# #### 2.	Построить график произвольной квадратичной функции, масштаб задать произвольно. Сделать настройки подписей осей, заголовка фигуры

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = 4 * x ** 2 - 2 * x + 5

fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(x, y, label='f(x) = 2x^2 - 3x + 1', color='cyan', linewidth=2)

plt.xlabel('X', ha='center')
plt.ylabel('Y', va='center', rotation=0, ha='center')
plt.title('График квадратичной функции')

plt.legend()

ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.grid(True)
plt.show()

# %% [markdown]
# #### 3.	Построить график произвольной гармонической функции, масштаб задать произвольно. Сделать настройки подписей осей, заголовка фигуры

# %%
x = np.linspace(0, 10, 100)

y = 4 * np.sin(3 * x + 5)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = A * sin(B * x + C)', color='g', linestyle='dashed', markerfacecolor='blue', marker='o',
         linewidth=3)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('График гармонической функции')

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# #### 4.	Вывести графики п.2 и 3 в разные поля при помощи функции subplot()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y1 = 4 * x ** 2 - 2 * x + 5
y2 = 4 * np.sin(3 * x + 5)

plt.figure(figsize=(12, 6))

ax = plt.subplot(1, 2, 1)
plt.plot(x, y1, label='f(x) = 2x^2 - 3x + 1', color='cyan', linewidth=2)
plt.xlabel('X', ha='center')
plt.ylabel('Y', va='center', rotation=0, ha='center')
plt.title('График квадратичной функции')
plt.legend()
plt.grid(True)

ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.subplot(1, 2, 2)
plt.plot(x, y2, label='f(x) = A * sin(B * x + C)', color='r', linewidth=2)
plt.xlabel('X', ha='center')
plt.ylabel('Y', va='center', rotation=0, ha='center')
plt.title('График гармонической функции')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.	Построить графики п.2 и 3 в одной координатной плоскости, сделать подписи графиков, указать легенду.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y1 = 4 * x ** 2 - 2 * x + 5
y2 = 4 * np.sin(3 * x + 5)

fig, ax1 = plt.subplots(figsize=(8, 6))

color = 'cyan'
ax1.set_xlabel('X')
ax1.set_ylabel('f(x) = 2x^2 - 3x + 1', color=color)
ax1.plot(x, y1, label='f(x) = 2x^2 - 3x + 1', color=color, linewidth=2)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

ax1.spines['left'].set_position('center')
ax1.spines['bottom'].set_position('zero')
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')

color = 'r'
ax2.set_ylabel('f(x) = A * sin(B * x + C)', color=color)
ax2.plot(x, y2, label='f(x) = A * sin(B * x + C)', color=color, linewidth=2)
ax2.tick_params(axis='y', labelcolor=color)

plt.title('Графики квадратичной и гармонической функций')
plt.grid(True)

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')

plt.show()

# %% [markdown]
# #### 6.	Построить график функции, заданной параметрически,
#
# # ${x(t)} = \cos(3t)$, $y(t) = \sin(2t)$, $\(t \in [0, 4\pi]\)$

# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.linspace(0, 4*np.pi, 1000)

x = np.cos(3 * t)
y = np.sin(2 * t)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='x(t) = cos(3t), y(t) = sin(2t)', color='b')


plt.xlabel('x')
plt.ylabel('y')
plt.title('Параметрический график функции')

plt.grid(True)

plt.legend()

plt.show()

# %% [markdown]
# #### 7.	Построить столбиковую диаграмму по данным статистического комитета КР по прожиточному минимуму, представленному в таблице

# %%
data = np.array([["Наименование показателей", 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, ],
             ["Кыргызская Республика", 4341.5, 4599.21, 4981.51, 5182.99, 4794.34, 4900.79, 4792.54, 4806.32, 5358.53,
              6268.31, 7178.32 ]])
data
# Out:
# array([['Наименование показателей', '2012', '2013', '2014', '2015',
#         '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#        ['Кыргызская Республика', '4341.5', '4599.21', '4981.51',
#         '5182.99', '4794.34', '4900.79', '4792.54', '4806.32', '5358.53',
#         '6268.31', '7178.32']], dtype='<U32')

# %%
years = data[0, 1:]
values = data[1, 1:]

plt.figure(figsize=(10, 6))
plt.bar(years, values, color='g', alpha=0.7)

plt.xlabel('Год')
plt.ylabel('Прожиточный минимум')
plt.title('Прожиточный минимум в Кыргызской Республике (2012-2022)')

plt.xticks(rotation=45)

plt.grid(axis='y')
plt.tight_layout()  
plt.show()

# %% [markdown]
# #### 8.	Построить круговой график по данным п. 7

# %%
years = data[0, 1:]
values = data[1, 1:]

max_value_index = np.argmax(values)

explode = [0.1 if i == max_value_index else 0 for i in range(len(years))]

plt.figure(figsize=(8, 8))
plt.pie(values, labels=years, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors, explode=explode)

plt.title('Прожиточный минимум в Кыргызской Республике (2012-2022)')

plt.axis('equal')
plt.show()

# %% [markdown]
# #### 9.	Построить график произвольной каркасной поверхности.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = np.outer(np.cos(u), np.sin(v))
y = np.outer(np.sin(u), np.sin(v))
z = np.outer(np.ones(np.size(u)), np.cos(v))


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.plot_wireframe(x, y, z, color='b', linewidth=0.5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Каркасная поверхность сферы')

plt.show()
